# %%
import json
import tempfile
import requests
import pathlib
from datetime import datetime as dt
from uuid import uuid4
from requests_oauthlib import OAuth1Session

# %%
consumer_key = '7GKwhJwazdDrgaXSzZvMrFGtT'
consumer_secret_key = 'ceLNls49QUtprrLCTDsjaXRLQJ4hGhKcIQKf4p7sfiXVcljZJM'

access_token = '551693427-9YxBcOd49wE6nKhNCeVX0RKURlc0rSPEMov9FoPR'
access_token_secret = 'UtKnwyytjObFs3RRXhVrIwruljYUB6xbCkzJf4nbzMVZf'

OUT_PATH = "/home/twitter22"
QUERY = "bolivia"
STOP_AFTER = 50

# %%
pathlib.Path(OUT_PATH).mkdir(parents=True, exist_ok=True)
query_data = {
    "track": f"#{QUERY}".replace("#", "").lower(),
    "language":"es",
}

# %%
twitter =  OAuth1Session(
    client_key=consumer_key,
    client_secret=consumer_secret_key,
    resource_owner_key=access_token,
    resource_owner_secret=access_token_secret,
)

# %%
url = "https://stream.twitter.com/1.1/statuses/filter.json"
query_url = f"{url}?{'&'.join([f'{k}={v}' for k,v in query_data.items()])}"

# %%
print(f"STREAMING {STOP_AFTER} TWEETS")
with twitter.get(query_url, stream=True) as response:
    for i, raw_tweet in enumerate(response.iter_lines()):
        if i == STOP_AFTER:
            break
        try:
            tweet = json.loads(raw_tweet)
            print(f"{i+1}/{STOP_AFTER}: {tweet['user']['screen_name']},{tweet['user']['location']} @ {tweet['created_at']}: {tweet['text']}\n")
            
        except (json.JSONDecodeError, KeyError) as err:
            print(f"{i+1}/{STOP_AFTER}: ERROR===>0of, encountered a mangled line of data here..\n")
            continue 
            
        with pathlib.Path(OUT_PATH) / f"{dt.now().timestamp()}_{uuid4()}.json" as F:
            F.write_bytes(raw_tweet)
# Out:
# STREAMING 50 TWEETS
# 1/50: PipopeCifuentes,Puebla, México @ Thu Nov 05 21:00:19 +0000 2020: RT @AlinaDuarte_: Alerta máxima #Bolivia. Luego de que grupos paramilitares estén sembrando dudas sobre la legitimidad de las elecciones de…
#
# 2/50: MarielaSCZ,None @ Thu Nov 05 21:00:21 +0000 2020: FRAUDE DESCARADO EN BOLIVIA https://t.co/sF08l8Ah10
#
# 3/50: Luis11750420,None @ Thu Nov 05 21:00:21 +0000 2020: RT @Mar53163624: #Bolivia 🇧🇴
# #LasRedesHablan 🗣️
# #inaudito
# AÑEZ OCULTÓ MÁS DE 5 MIL TUBOS DE OXÍGENO EN PLENA PANDEMIA
#
# Vía: La Resistencia…
#
# 4/50: DanielCatalano_,Ciudad Autónoma de Buenos Aire @ Thu Nov 05 21:00:22 +0000 2020: Hoy a la mañana estuvimos junto a Carlos Girotti visitando a @evoespueblo charlando sobre las elecciones y la recup… https://t.co/lyz9egKTP1
#
# 5/50: danielhojaverde,None @ Thu Nov 05 21:00:22 +0000 2020: RT @AlinaDuarte_: Alerta máxima #Bolivia. Luego de que grupos paramilitares estén sembrando dudas sobre la legitimidad de las elecciones de…
#
# 6/50: JLmelgacho,None @ Thu Nov 05 21:00:24 +0000 2020: RT @BoliviaLibreNow: #BOLIVIA La DERECHA extrema RECURSOS
#
# Recurre a todo con razón o sin razón
# La consigna, Q NO GOBIERNE el MAS
#
# Q Boli…
#
# 7/50: BossMovil,El Paraíso Mundial @ Thu Nov 05 21:00:26 +0000 2020: RT @vanessavallej0: Esto no es más que los colectivos de Venezuela;
#
# 8/50: reina8a5,Cagua Edo Aragua @ Thu Nov 05 21:00:27 +0000 2020: RT @ellamararodrig1: #ULTIMAHORA
# 🛑Ya salió el informe final de la OEA sobre las elecciones en #Bolivia.
#
# En resumen dicen que nuestros voto…
#
# 9/50: AntonioParient2,None @ Thu Nov 05 21:00:27 +0000 2020: RT @CapitanBitcoin: El español, idioma oficial en: Argentina, Bolivia, Chile, Colombia, Costa Rica, Cuba, Rep. Dominicana, Ecuador, El Salv…
#
# 10/50: PNUDLAC,América Latina y el Caribe @ Thu Nov 05 21:00:33 +0000 2020: 🇧🇴En la senda de la recuperación del desarrollo: ¿Cuáles con los retos de #Bolivia en la #recuperación después del… https://t.co/yiuBEs83j8
#
# 11/50: CantaAbroCS,Cantabria, España @ Thu Nov 05 21:00:35 +0000 2020: No se los demás, pero yo ya estoy cansándome de ver que el rey tiene que lidiar con los comunistas.
#
# La @CasaReal d… https://t.co/mmQzz94eYf
#
# 12/50: Ozu28435324,None @ Thu Nov 05 21:00:35 +0000 2020: RT @jaralezo: Todos los países latinoamericanos tienen varias lenguas.
#
# -En Colombia hay unas 70 lenguas.
# -Perú unas 60.
# -México unas 50.…
#
# 13/50: PorAmoraVzla79,Maracaibo, Venezuela @ Thu Nov 05 21:00:37 +0000 2020: RT @RNVinformativa: #EnVivo @dcabellor: Almagro no escribe nada sobre EE.UU, es bueno para meterse en los asuntos internos de Bolivia y dar…
#
# 14/50: sabinalberdi,madrid @ Thu Nov 05 21:00:38 +0000 2020: RT @jonathanmartinz: Lo han hecho en Bolivia, en Venezuela o en Honduras. La última tendencia del retropopulismo pasa por poner en cuestión…
#
# 15/50: tato_barato,None @ Thu Nov 05 21:00:39 +0000 2020: RT @AlinaDuarte_: Alerta máxima #Bolivia. Luego de que grupos paramilitares estén sembrando dudas sobre la legitimidad de las elecciones de…
#
# 16/50: re_curiosito,None @ Thu Nov 05 21:00:39 +0000 2020: MASISTAS EN EMERGENCIA
# Cochabamba: Se destapan pugnas y denuncias de coima por pegas en el #MAS.
# Denuncian que hijo… https://t.co/tDRe9QMZCg
#
# 17/50: ichig0tchi,chile @ Thu Nov 05 21:00:39 +0000 2020: RT @AlinaDuarte_: Alerta máxima #Bolivia. Luego de que grupos paramilitares estén sembrando dudas sobre la legitimidad de las elecciones de…
#
# 18/50: CITRIPIO4,Bolivia  @ Thu Nov 05 21:00:40 +0000 2020: RT @AgustinZambrana: Chequea Bolivia señala que es falso que "activista, Melisa Ibarra Rosario, habría amenazado con asesinar al nuevo pres…
#
# 19/50: SEGUDI01,San Miguel de Tucumán, Argenti @ Thu Nov 05 21:00:43 +0000 2020: Se fueron @mauriciomacri , @JeanineAnez y @realDonaldTrump , le toca  a Ud. @jairbolsonaro .
#
# Bolivia, Venezuela y… https://t.co/oOSIX6hbyE
#
# 20/50: Divalujo,None @ Thu Nov 05 21:00:43 +0000 2020: RT @evoespueblo: Luego de las elecciones, urge trabajar para reconstruir la Patria; no son tiempos de confrontación sino de concertación y…
#
# 21/50: juanmarg14,Tacubaya, DF, México @ Thu Nov 05 21:00:44 +0000 2020: RT @AlinaDuarte_: Alerta máxima #Bolivia. Luego de que grupos paramilitares estén sembrando dudas sobre la legitimidad de las elecciones de…
#
# 22/50: cubisima2020,None @ Thu Nov 05 21:00:45 +0000 2020: RT @rolandoteleSUR: Gobierno de Facto en pleno #Bolivia
#
# 23/50: deangeluz22,None @ Thu Nov 05 21:00:46 +0000 2020: Todo el mundo lo sabe
#
# 24/50: hazaf,None @ Thu Nov 05 21:00:47 +0000 2020: @Almagro_OEA2015 @EsdrasALopez @OEA_oficial No vas a meter orden en USA, como lo hiciste en Bolivia?
#
# 25/50: MaSoledadVP,Desde un punto de América @ Thu Nov 05 21:00:54 +0000 2020: RT @marcoporchile: ¿Y @Almagro_OEA2015 se quedó sin wifi? Ha quedado demostrada su vergonzosa intervención en las elecciones de Bolivia hac…
#
# 26/50: Diego34999715,None @ Thu Nov 05 21:00:54 +0000 2020: RT @JorgeGestoso: El tweet d Trump diciendo “paren de contar los votos”provocó duras críticas a nivel mundial. Se imaginan si el año pasado…
#
# 27/50: study_and_win,None @ Thu Nov 05 21:00:56 +0000 2020: Amenaza a domicilios en el departamento de La Paz #Bolivia
# #Apoyar_LaPaz
# #Boliviafraude
#
# 28/50: CITRIPIO4,Bolivia  @ Thu Nov 05 21:00:59 +0000 2020: RT @AdriAeroshk: @edgarinvillegas Querido Edgar, estamos contigo!
# https://t.co/mitYsbL4C1 https://t.co/koGdUAL5WP
#
# 29/50: DoNkeN00,None @ Thu Nov 05 21:00:59 +0000 2020: RT @LaUltima_Hora: ‼️ Un ultraderechista español amenaza a los delegados de Unidas Podemos en Bolivia
#
# La persona que les increpó se encont…
#
# 30/50: Matapollos17,None @ Thu Nov 05 21:01:00 +0000 2020: RT @golondrina_bo: Otro pitita se suma a la lista de llorones.
#
# Iván Rojas, ex jefe de la policía que lideró la persecución política al MAS…
#
# 31/50: AdriAeroshk,None @ Thu Nov 05 21:01:02 +0000 2020: RT @DeMilenca1: .@Almagro_OEA2015 Dada la delicada circunstancia de la crisis social,política de #Bolivia, solicitamos a través suyo y ante…
#
# 32/50: meloinvento044,None @ Thu Nov 05 21:01:04 +0000 2020: RT @jaralezo: Todos los países latinoamericanos tienen varias lenguas.
#
# -En Colombia hay unas 70 lenguas.
# -Perú unas 60.
# -México unas 50.…
#
# 33/50: Damarys2206,Caracas @ Thu Nov 05 21:01:04 +0000 2020: RT @ProgresaLatam: A propósito de los votos tardíos pero legítimos en EEUU y las acusaciones de fraude de la campaña trumpista, ¿dónde esta…
#
# 34/50: gramirez1811,None @ Thu Nov 05 21:01:05 +0000 2020: RT @joseantoniokast: Hoy estaré conversando con @javiercolchane, Alcalde de Colchane sobre el impacto de la crisis migratoria en el norte d…
#
# 35/50: lilibalu,None @ Thu Nov 05 21:01:07 +0000 2020: RT @canguil31: PROCESO PENAL CONTRA TODOS LOS SEDICIOSOS.
# BOLIVIA NO PUEDE VIVIR EN LA SOZOBRA.
# QUEREMOS TRABAJAR, QUEREMOS PAZ.
#
# 36/50: boriszaurio,La Paz Bolivia @ Thu Nov 05 21:01:07 +0000 2020: RT @HackmeetingB0: Transmisión en vivo del evento, Twitch en Vivo, Viernes 6 desde las 18:30, Sábado 7 desde las 15:00 y domingo 8 desde la…
#
# 37/50: sanflowers__,✨;엔시티 @ Thu Nov 05 21:01:07 +0000 2020: RT @wosistas: 💣 "Mugre", 05/11
#
# 🇦🇷 Argentina 19 hs.
# 🇨🇱 Chile 19.00 hs.⁣
# 🇺🇾 Uruguay 19.00 hs. ⁣
# 🇲🇽 México 17.00 hs.⁣
# 🇨🇴 Colombia 17.00 hs.⁣…
#
# 38/50: fribera_,None @ Thu Nov 05 21:01:09 +0000 2020: @IdiazAyuso En España el Español deja de ser lengua oficial, y si lo es.en Méjico, Bolivia, Colombia, Perú...., 🤦‍♂️🤷‍♂️
#
# 39/50: lagunas_cano,Ciudad de México @ Thu Nov 05 21:01:10 +0000 2020: RT @AlinaDuarte_: Alerta máxima #Bolivia. Luego de que grupos paramilitares estén sembrando dudas sobre la legitimidad de las elecciones de…
#
# 40/50: ragl275,Almería, España @ Thu Nov 05 21:01:12 +0000 2020: RT @SeixoDani: Lo que no es normal es que los mismos que veían como un pucherazo claro lo de Bolivia por un retraso de unas horas, ahora no…
#
# 41/50: zarcoman,México @ Thu Nov 05 21:01:12 +0000 2020: @Almagro_OEA2015 En USA es necesario dar un golpe de estado por las irregularidades en la eleccion así como en #Bolivia
#
# 42/50: QQQQQUIM,None @ Thu Nov 05 21:01:15 +0000 2020: RT @jonathanmartinz: Lo han hecho en Bolivia, en Venezuela o en Honduras. La última tendencia del retropopulismo pasa por poner en cuestión…
#
# 43/50: ricardocaba2,None @ Thu Nov 05 21:01:20 +0000 2020: RT @ChalecosAmarill: 🎥🛑En #Bolivia la COB y organizaciones sociales resguardaran la posesión del presidente electo .@LuchoXBolivia.
#
# 🔻Boliv…
#
# 44/50: katiagumucio,BOLIVIA @ Thu Nov 05 21:01:20 +0000 2020: RT @grupoeldeber: Apertura. El fiscal general del Estado también dijo que esta situación se dio por el cambio de domicilio de los investiga…
# 45/50: NSilva1989,None @ Thu Nov 05 21:01:21 +0000 2020: RT @NoBombardeenUIO: Qué "fraude" más aburrido 😴
#
# A esta hora en Bolivia ya había informes express de la OEA, una rubia jurando con Biblia…
#
# 46/50: GretaValdiviezo,Ecuador @ Thu Nov 05 21:01:27 +0000 2020: RT @JorgeGestoso: El tweet d Trump diciendo “paren de contar los votos”provocó duras críticas a nivel mundial. Se imaginan si el año pasado…
#
# 47/50: Arpatt,Buenos Aires, Argentina @ Thu Nov 05 21:01:29 +0000 2020: RT @Mateosmatat: Antes de volver a Bolivia, Evo Morales almorzó con sindicalistas argentinos https://t.co/CA8CxP5Huo
#
# 48/50: Ivang593,None @ Thu Nov 05 21:01:30 +0000 2020: RT @marcoporchile: ¿Y @Almagro_OEA2015 se quedó sin wifi? Ha quedado demostrada su vergonzosa intervención en las elecciones de Bolivia hac…
#
# 49/50: Antonio67181640,None @ Thu Nov 05 21:01:31 +0000 2020: Viendo las elecciones en USA, lo que pasa en Rusia, china, Venezuela, Nicaragua, Argentina,Corea del Norte, Bolivia… https://t.co/qtUKj1DXcJ
#
# 50/50: HeRbErT26032011,None @ Thu Nov 05 21:01:32 +0000 2020: RT @federicoalves: @LuciaIreneTrepp @EvaSaraLandau @EvaCopa_Bol La chica @LuciaIreneTrepp es socialista, sólo que aún no lo sabe. Expresó "…
